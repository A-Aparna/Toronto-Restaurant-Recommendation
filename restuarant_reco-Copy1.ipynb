# %%
import pandas as pd
import numpy as np
import time

# %% [markdown]
# AIzaSyD5dw3Coq7Fk4dkiiF4Vdb5OYzDu1GvvPU   -Google API key

# %%
ab=pd.read_json('yelp_academic_dataset_business.json',lines=True)

# %%
ab.head()
# Out:
#                           address  \
# 0     2818 E Camino Acequia Drive
# 1            30 Eglinton Avenue W
# 2       10110 Johnston Rd, Ste 15
# 3   15655 W Roosevelt St, Ste 237
# 4  4209 Stuart Andrew Blvd, Ste F
#
#                                           attributes             business_id  \
# 0                           {'GoodForKids': 'False'}  1SWheh84yJXfytovILXOAQ
# 1  {'RestaurantsReservations': 'True', 'GoodForMe...  QXAEGFB4oINsVuTFxEYKFQ
# 2  {'GoodForKids': 'True', 'NoiseLevel': 'u'avera...  gnKjwL_1w79qoiV3IC_xQQ
# 3                                               None  xvX2CttrVhyG2z1dFg_0xw
# 4  {'BusinessAcceptsBitcoin': 'False', 'ByAppoint...  HhyxOkGAM07SRYtlQ4wMFQ
#
#                                           categories         city  \
# 0                                  Golf, Active Life      Phoenix
# 1  Specialty Food, Restaurants, Dim Sum, Imported...  Mississauga
# 2                  Sushi Bars, Restaurants, Japanese    Charlotte
# ...

# %%
df=ab.where((ab["city"]=="Toronto") | (ab["city"]=="Tornto" )| (ab["city"]=="Downtown Toronto"))
df=df.dropna()
df.reset_index(drop=True)
# Out:
#                                              address  \
# 0                       445 King Street W, Suite 101
# 1                        865 York Mills Road, Unit 1
# 2                                      26 Bellair St
# 3                                1170 Queen Street W
# 4                                1051 Bloor Street W
# 5                                 582 College Street
# 6                                1614 Queen Street E
# 7                               5241 Dundas Street W
# 8                            165 East Liberty Street
# 9                                  105 The Pond Road
# 10                                1732 Kingston Road
# 11                         1346 Queen Street, Unit 2
# 12                             322 Adelaide Street W
# 13                           270 Wellington Street W
# 14                            1448 Lawrence Avenue E
# 15                             1513 Gerrard Street E
# 16                                 3342 Yonge Street
# ...

# %%
df.where(df["city"]=="nan").count()
# Out:
# address         0
# attributes      0
# business_id     0
# categories      0
# city            0
# hours           0
# is_open         0
# latitude        0
# longitude       0
# name            0
# postal_code     0
# review_count    0
# stars           0
# state           0
# dtype: int64

# %%
#df['categories'].str.contains('Restaurants')

# %%
#df=df.where(df['categories'].str.contains('Restaurants'))

# %%
df["city"].unique()
# Out:
# array(['Toronto', 'Downtown Toronto', 'Tornto'], dtype=object)

# %%
df.count()
# Out:
# address         12172
# attributes      12172
# business_id     12172
# categories      12172
# city            12172
# hours           12172
# is_open         12172
# latitude        12172
# longitude       12172
# name            12172
# postal_code     12172
# review_count    12172
# stars           12172
# state           12172
# dtype: int64

# %%
#kw='Restuarants'
df_food=df[df['categories'].str.contains('Restaurants')]
df_food.reset_index(drop=True)
df_food
# Out:
#                                                   address  \
# 29                                    1170 Queen Street W
# 32                                    1051 Bloor Street W
# 50                                     582 College Street
# 96                                    1614 Queen Street E
# 107                                  5241 Dundas Street W
# 116                               165 East Liberty Street
# 119                                     105 The Pond Road
# 121                                    1732 Kingston Road
# 125                             1346 Queen Street, Unit 2
# 159                                 322 Adelaide Street W
# 166                                1448 Lawrence Avenue E
# 185                             2945 Lake Shore Boulevard
# 190                               523 Mount Pleasant Road
# 285                                    971 O'Connor Drive
# 293                                     291 King Street W
# ...

# %%
df_to_use=df_food[['address','categories','city','name','stars']]

# %%
pd.DataFrame(df_to_use).to_excel('yelp_Toronto.xlsx', header=True, index=False)

# %%
df=pd.read_excel('restaurants_toronto_main1.xlsx')

# %%
df
# Out:
#                                                 address  \
# 0                                   1170 Queen Street W
# 1                                   1051 Bloor Street W
# 2                                    582 College Street
# 3                                   1614 Queen Street E
# 4                               165 East Liberty Street
# 5                                    1732 Kingston Road
# 6                                1448 Lawrence Avenue E
# 7                             2945 Lake Shore Boulevard
# 8                               523 Mount Pleasant Road
# 9                                    971 O'Connor Drive
# 10                                    291 King Street W
# 11                            1822 Saint Clair Avenue W
# 12            40 King Street W, Scotia plaza Food Court
# 13                                  2901 Bayview Avenue
# 14                                  402 Danforth Avenue
# 15    1 First Canadian Place, Food Terrace, Upper Level
# ...

# %%
df=df.dropna()
df=df.reset_index(drop=True)

# %%
df['cuisine']='NA'
df=df.copy()

# %% [markdown]
# words=np.array(['Mexican','Indian','Japan','Italian'])
# for word in words:
#     print(word)
#     df_to_use['cuisine']=df['categories'].str.contains(word)
#     print(df_to_use.head())
#     df['cuisine']=df_to_use['cuisine'].map({True:word})
#     print(df.head())

# %%
def cuisine_type(row):
    words=np.array(['Mexican','Indian','Japan','Italian','Middle','Thai','Chinese','Mediterranean','Canadian',\
                    'Greek','Peruvian','Breakfast & Brunch','Sushi','Baker','Juice','Barbeque','Korean','French',\
                   'Vietnamese'])
    for word in words:
        if (row.find(word) != -1) :
            return word
        
    return None
    
df['cuisine']=df['categories'].apply(cuisine_type)

# %%
def condense_cuisine(row):
    if (row=='Sushi' or row=='Korean'):
        return 'Japan'
    if (row=='Vietnamese' ):
        return 'Thai'
    if (row=='French' or row=='Italian'):
        return 'European'
    if (row=='Greek' or row=='Middle'):
        return 'Mediterranean'
    if (row=='Baker' or row=='Juice'):
        return 'Dessert'
    if (row=='Barbeque'):
        return 'Canadian'
    else:
        return row
    return None
df['cuisine']=df['cuisine'].apply(condense_cuisine)

# %%
df.groupby('cuisine').count()
# Out:
#                     address  categories  city  name  stars
# cuisine
# Breakfast & Brunch      400         400   400   400    400
# Canadian                606         606   606   606    606
# Chinese                 368         368   368   368    368
# European                591         591   591   591    591
# Indian                  238         238   238   238    238
# Japan                   597         597   597   597    597
# Mediterranean           637         637   637   637    637
# Mexican                 223         223   223   223    223
# Peruvian                 13          13    13    13     13
# Thai                    256         256   256   256    256

# %%
d2=df.groupby('cuisine').count()
d2
# Out:
#                     address  categories  city  name  stars
# cuisine
# Breakfast & Brunch      400         400   400   400    400
# Canadian                606         606   606   606    606
# Chinese                 368         368   368   368    368
# European                591         591   591   591    591
# Indian                  238         238   238   238    238
# Japan                   597         597   597   597    597
# Mediterranean           637         637   637   637    637
# Mexican                 223         223   223   223    223
# Peruvian                 13          13    13    13     13
# Thai                    256         256   256   256    256

# %%
df_to_use.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-23e228058dfb> in <module>
# ----> 1 df_to_use.head()
#
# NameError: name 'df_to_use' is not defined

# %%
#df_to_use.reset_index()
#df_to_use

# %%
#sea="Bolt Fresh Bar"
# Out:
# 'Burrito Bandidos'

# %%
import webbrowser
import requests
from bs4 import BeautifulSoup
import json

# %% [markdown]
# https://kgsearch.googleapis.com/v1/entities:search?query=art square cafe&key=AIzaSyD5dw3Coq7Fk4dkiiF4Vdb5OYzDu1GvvPU

# %%
url="https://www.google.com.tr/search?q={}".format(sea)
response = requests.get(url)
print(url)
##print(response.text)
soup = BeautifulSoup(response.text, 'lxml')
print(soup)
#class bneawe shorlisted for the website
#div_html = 
for div_html in soup.findAll('div', {"class" : "BNeawe UPmit AP7Wnd"}):
    print(div_html.text)
diva = soup.find('a')
div = soup.findAll('span', {"class" : "r0bn4c rQMQod"})

#text = div.string
print(div_html)
print(div)
headlines = soup.find('div')
#headlines
# Out:
# https://www.google.com.tr/search?q=Art Square Cafe
# <!DOCTYPE html>
# <html lang="en-CA"><head><meta charset="utf-8"/><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/><title>Art Square Cafe - Google Search</title><script nonce="eP4R0+7gZKF8gbjm1K1EpQ==">(function(){
# document.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"==c||"q"==c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!=document.documentElement;a=a.parentElement)if("A"==a.tagName){a="1"==a.getAttribute("data-nohref");break a}a=!1}a&&b.preventDefault()},!0);}).call(this);(function(){
# ...

# %%
print(headlines)
print(soup.find('div', {"class" : "BNeawe UPmit AP7Wnd"}).text)
# Out:
# <div class="cOl4Id"><a href="/?sa=X&amp;ved=0ahUKEwih9q-45aTnAhUEcq0KHSb1CygQOwgC"><span class="V6gwVd">G</span><span class="iWkuvd">o</span><span class="cDrQ7">o</span><span class="V6gwVd">g</span><span class="ntlR9">l</span><span class="iWkuvd tJ3Myc">e</span></a></div>
# https://www.boltfreshbar.com

# %%
response = requests.get(url)
print(url)
##print(response.text)
soup = BeautifulSoup(response.text, 'lxml')
#class bneawe shorlisted for the website
div_html = soup.find('div', {"class" : "BNeawe UPmit AP7Wnd"})
#, {"class" : "BNeawe UPmit AP7Wnd"}
print(div_html.text)
# Out:
# https://www.google.com.tr/search?q=Bolt Fresh Bar
# https://www.boltfreshbar.com

# %%
df['link']='NA'

# %%
df.head()
# Out:
#                    address                                         categories  \
# 0      1170 Queen Street W  Juice Bars & Smoothies, Food, Restaurants, Fas...
# 1      1051 Bloor Street W  Restaurants, Nightlife, Breakfast & Brunch, Ve...
# 2       582 College Street  Restaurants, Breakfast & Brunch, Bars, Modern ...
# 3      1614 Queen Street E                      Tex-Mex, Mexican, Restaurants
# 4  165 East Liberty Street  Middle Eastern, Restaurants, Salad, Breakfast ...
#
#       city                   name  stars             cuisine link cost
# 0  Toronto         Bolt Fresh Bar    3.0       Mediterranean   NA   NA
# 1  Toronto  The Steady Cafe & Bar    3.5  Breakfast & Brunch   NA   NA
# 2  Toronto     Mad Crush Wine Bar    4.0  Breakfast & Brunch   NA   NA
# 3  Toronto       Burrito Bandidos    3.5             Mexican   NA   NA
# 4  Toronto   Paramount Fine Foods    2.0       Mediterranean   NA   NA

# %%
def link_cost(row):
    #print(row)
    url="https://www.google.com.tr/search?q={}".format(row)
    response = requests.get(url)
    #print(url)
##print(response.text)
    soup = BeautifulSoup(response.text, 'lxml')
#class bneawe shorlisted for the website
    div_html = soup.find('div', {"class" : "BNeawe UPmit AP7Wnd"})
    print(div_html.text)
    return div_html.text

# %%
df['cost']='NA'

# %%
sea=df["name"][3]
sea
# Out:
# 'Burrito Bandidos'

# %%
def cost(row):
    cost=0
    word=['Under $10','$11-30','$31-60','Over $61']
    #print(row)
    list_1=['$','$$','$$$'] 
    time.sleep(10)
    url="https://www.google.com.tr/search?q={}".format(row)
    response = requests.get(url)
    #print(url)
    #print(response.text)
    soup = BeautifulSoup(response.text, 'lxml')
    #print(soup)
    #r0bn4c rQMQod
    div = soup.find_all('span', class_= "r0bn4c rQMQod")
    #print(div)
    for tag in soup.find_all('span', class_= "r0bn4c rQMQod"):
        #print(tag)
        abc=tag.text
        #print(abc)
        for i in word:
            #print(i)
            if (abc.find(i) != -1) :
                print(abc)
                if abc==word[0]:
                    cost=1
                if abc==word[1]:
                    cost=2
                if abc==word[2]:
                    cost=3
                elif abc==word[3]:
                    cost=4
    return cost

# %% [markdown]
# $= under $10. $$=11-30. $$$=31-60. $$$$= over $61

# %%
a=cost(sea)
a
# Out:
# Under $10
# 1

# %%
df['cost'].loc[2001:3950]=df['name'].loc[2001:3950].apply(cost)
# Out:
# $31-60
# Under $10
# Under $10
# $11-30
# Under $10
# $11-30
# $31-60
# $31-60
# $11-30
# $11-30
# $11-30
# $31-60
# $11-30
# $11-30
# $11-30
# Under $10
# Under $10
# $11-30
# $31-60
# Under $10
# Under $10
# $11-30
# CA$11-30
# CA$11-30
# $11-30
# $11-30
# $11-30
# CA$11-30
# $11-30
# $11-30
# CA$11-30
# Under $10
# Under $10
# Under $10
# $11-30
# $11-30
# $11-30
# $11-30
# Under $10
# $11-30
# CA$11-30
# CA$11-30
# $11-30
# $11-30
# Under $10
# $11-30
# Under $10
# Under $10
# $11-30
# $11-30
# $31-60
# $31-60
# $11-30
# Under $10
# Under $10
# $31-60
# $11-30
# Under $10
# $11-30
# Under $10
# $11-30
# $31-60
# $11-30
# CA$11-30
# Under $10
# $11-30
# $11-30
# $11-30
# CA$11-30
# $31-60
# Under $10
# $11-30
# $11-30
# $11-30
# $11-30
# $11-30
# $11-30
# $11-30
# Under $10
# $11-30
# $11-30
# Under $10
# $11-30
# CA$11-30
# $11-30
# Under $10
# $11-30
# $11-30
# CA$11-30
# Under $10
# $11-30
# $11-30
# CA$11-30
# Under $10
# Under $10
# $11-30
# $11-30
# Under $10
# $11-30
# ...

# %%
df_to_use['link']=df_to_use['name'].apply(link_cost)

# %%
df=df.dropna()
df=df.reset_index(drop=True)

# %%
df_to_use['link']=df_to_use['name'].apply(link_cost)
# Out:
# Bolt Fresh Bar
# https://www.google.com.tr/search?q=Bolt Fresh Bar
# <div class="BNeawe UPmit AP7Wnd">https://www.boltfreshbar.com</div>
# The Steady Cafe & Bar
# https://www.google.com.tr/search?q=The Steady Cafe & Bar
# <div class="BNeawe UPmit AP7Wnd">https://www.facebook.com › Places › Toronto, Ontario › Dive Bar</div>
# Mad Crush Wine Bar
# https://www.google.com.tr/search?q=Mad Crush Wine Bar
# <div class="BNeawe UPmit AP7Wnd">https://www.blogto.com › 2018/09 › mad-crush-wine-bar-suddenly-closed</div>
# Burrito Bandidos
# https://www.google.com.tr/search?q=Burrito Bandidos
# <div class="BNeawe UPmit AP7Wnd">www.burritobandidos.com</div>
# Medium Rare
# https://www.google.com.tr/search?q=Medium Rare
# <div class="BNeawe UPmit AP7Wnd">www.mediumrare.to</div>
# Paramount Fine Foods
# https://www.google.com.tr/search?q=Paramount Fine Foods
# <div class="BNeawe UPmit AP7Wnd">https://www.paramountfinefoods.com</div>
# Aroma Espresso Bar
# ...

# %%
df['link'].loc[1003:1005]=df['name'].loc[1003:1005].apply(link_cost)
# Out:
# lapalma.ca
# https://www.tripadvisor.ca › ... › Ontario › Toronto › Toronto Restaurants
# https://torontolife.com › food › restaurants › cluck-grunt-and-low-silenced-...

# %%
df
# Out:
#                                                 address  \
# 0                                   1170 Queen Street W
# 1                                   1051 Bloor Street W
# 2                                    582 College Street
# 3                                   1614 Queen Street E
# 4                               165 East Liberty Street
# 5                                    1732 Kingston Road
# 6                                1448 Lawrence Avenue E
# 7                             2945 Lake Shore Boulevard
# 8                               523 Mount Pleasant Road
# 9                                    971 O'Connor Drive
# 10                                    291 King Street W
# 11                            1822 Saint Clair Avenue W
# 12            40 King Street W, Scotia plaza Food Court
# 13                                  2901 Bayview Avenue
# 14                                  402 Danforth Avenue
# 15    1 First Canadian Place, Food Terrace, Upper Level
# ...

# %%
df.groupby('cost').count()
# Out:
#       address  categories  city  name  stars  cuisine
# cost
# 0.0       627         627   627   627    627      627
# 1.0       822         822   822   822    822      822
# 2.0      2183        2183  2183  2183   2183     2183
# 3.0       297         297   297   297    297      297

# %%
    cost=0
    list_1=['$','$$','$$$']    
    div = soup.find_all('span', class_= "r0bn4c rQMQod")
    for tag in soup.find_all('span', class_= "r0bn4c rQMQod"):
    #print(tag)
        abc=tag.text
        for abc in list_1:
        #print(tag.text)
            if tag.text=='$':
                cost=1
            if tag.text=='$$':
                cost=2
            elif tag.text=='$$$':
                cost=3
        else:
            cost=0

# %%
import requests
from bs4 import BeautifulSoup
import json

# %%
from pandas import ExcelWriter
from pandas import ExcelFile

# %%
pd.DataFrame(df).to_excel('restaurants_toronto_main_cost3_proper.xlsx', index=False)

# %%
df.head()
# Out:
# address        object
# categories     object
# city           object
# name           object
# stars         float64
# dtype: object

# %%
df=pd.read_excel('restaurants_toronto_main_cost3_proper.xlsx')

# %%
df
# Out:
#                                                 address  \
# 0                                   1170 Queen Street W
# 1                                   1051 Bloor Street W
# 2                                    582 College Street
# 3                                   1614 Queen Street E
# 4                               165 East Liberty Street
# 5                                    1732 Kingston Road
# 6                                1448 Lawrence Avenue E
# 7                             2945 Lake Shore Boulevard
# 8                               523 Mount Pleasant Road
# 9                                    971 O'Connor Drive
# 10                                    291 King Street W
# 11                            1822 Saint Clair Avenue W
# 12            40 King Street W, Scotia plaza Food Court
# 13                                  2901 Bayview Avenue
# 14                                  402 Danforth Avenue
# 15    1 First Canadian Place, Food Terrace, Upper Level
# ...

# %%
p1=df.where(df['cost']==0)
p1=p1.dropna()
p1
# Out:
#                                                 address  \
# 0                                   1170 Queen Street W
# 4                               165 East Liberty Street
# 6                                1448 Lawrence Avenue E
# 8                               523 Mount Pleasant Road
# 13                                  2901 Bayview Avenue
# 15    1 First Canadian Place, Food Terrace, Upper Level
# 16                                   667 College Street
# 19                                    997 Dupont Street
# 20                                  1150 College Street
# 26                                   228 Queen Street W
# 29                                  322 Bathurst Street
# 30                              617 Mount Pleasant Road
# 39                                 303 King Street West
# 40                                    401 King Street W
# 44                                 2861 Dundas Street W
# 46                                        580 Church St
# ...

# %%
def update_cost(row):   
    print(row)
    cost=0
    list_1=['$','$$','$$$'] 
    time.sleep(5)
    url="https://www.google.com.tr/search?q={}".format(row)
    response = requests.get(url)
    #print(url)
    #print(response.text)
    soup = BeautifulSoup(response.text, 'lxml')
    div = soup.find_all('span', class_= "r0bn4c rQMQod")
    for tag in soup.find_all('span', class_= "r0bn4c rQMQod"):
    #print(tag)
        abc=tag.text
        for abc in list_1:
        #print(tag.text)
            if (tag.text=='$' or tag.text=='$ - $$'):
                cost=1
            if (tag.text=='$$' or tag.text=='$$ - $$$'):
                cost=2
            elif tag.text=='$$$':
                cost=3
    return cost

# %%
p1['cost'].loc[0:3950]=p1['name'].loc[0:3950].apply(update_cost)
# Out:
# Bolt Fresh Bar
# Paramount Fine Foods
# Caffeine
# Pallucci
# Bread & Roses Bakery Cafe
# Maman
# The Standard Pizza & Pasta Bar
# PICEA997
# Brockton Haunt
# Pizza Pizza
# Bathurst Local
# Jules Cafe Patisserie
# HUSH
# Bloke & 4th
# D & Y Sushi
# Fuzion
# Earth Rosedale
# Fare Game Continental Cuisine
# Dear & Fro
# Back of House
# The Fix + Co
# Yuzu Izakaya
# Chinese Dumplings
# Konnichiwa
# Locus144
# The Mad Italian
# Nook
# PROP
# Al Pastor
# Ivory Thailand
# Muckish Irish Pub
# Cloud Free Agent Espresso Bar
# Rose and Sons Swan
# Lamb Kebab - Savory Chinese Crepes
# Pho Kimboss Bistro
# BarBurrito - Gerrard
# Kirei Sushi + Bar
# AprilÃ© Bambina
# Edo
# Sicilian Sidewalk Cafe
# Old Beijing BBQ
# Maru & Maru Sake Bar
# Littlefish
# China Town
# Atsa Matta For You? Trattoria
# Shari
# Uncle Tetsu's Japanese Angel Cafe
# Paramount Fine Foods
# Starbucks
# Spicy Aroma
# Kenzo
# Chef of India
# Chicken Monster
# Dundas Garden
# Tim Hortons
# Mexicados Burritos & Bowls
# ...

# %%
p1
# Out:
#                                                 address  \
# 0                                   1170 Queen Street W
# 4                               165 East Liberty Street
# 6                                1448 Lawrence Avenue E
# 8                               523 Mount Pleasant Road
# 13                                  2901 Bayview Avenue
# 15    1 First Canadian Place, Food Terrace, Upper Level
# 16                                   667 College Street
# 19                                    997 Dupont Street
# 20                                  1150 College Street
# 26                                   228 Queen Street W
# 29                                  322 Bathurst Street
# 30                              617 Mount Pleasant Road
# 39                                 303 King Street West
# 40                                    401 King Street W
# 44                                 2861 Dundas Street W
# 46                                        580 Church St
# ...

# %%
pd.DataFrame(p1).to_excel('restaurants_toronto_main_cost_only0_update.xlsx', index=False)

# %%
p1.groupby('cost').count()
# Out:
#       address  categories  city  name  stars  cuisine
# cost
# 0         627         627   627   627    627      627
# 1         128         128   128   128    128      128
# 2         245         245   245   245    245      245
# 3          14          14    14    14     14       14

# %%
df.update(p1)
df
# Out:
#                                                 address  \
# 0                                   1170 Queen Street W
# 1                                   1051 Bloor Street W
# 2                                    582 College Street
# 3                                   1614 Queen Street E
# 4                               165 East Liberty Street
# 5                                    1732 Kingston Road
# 6                                1448 Lawrence Avenue E
# 7                             2945 Lake Shore Boulevard
# 8                               523 Mount Pleasant Road
# 9                                    971 O'Connor Drive
# 10                                    291 King Street W
# 11                            1822 Saint Clair Avenue W
# 12            40 King Street W, Scotia plaza Food Court
# 13                                  2901 Bayview Avenue
# 14                                  402 Danforth Avenue
# 15    1 First Canadian Place, Food Terrace, Upper Level
# ...

# %%
df.dtypes
# Out:
# dtype('O')

# %%
df=df.astype({'cost': 'int32'}).dtypes

# %%
df
# Out:
# address        object
# categories     object
# city           object
# name           object
# stars         float64
# cuisine        object
# cost            int32
# dtype: object
